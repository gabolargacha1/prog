# %% [markdown]
# <a href="https://colab.research.google.com/github/gabolargacha1/prog/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # test
# prueba de **texto**
#
# ```
# # Esto tiene formato de código
# ```

# %%
from google.colab import drive  
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # importar librerias

# %%
# importar librerias
import numpy as np
import matplotlib.pyplot as plt
import cv2

# graficar imagenes estaticas en el notebook
# %matplotlib inline

# %% [markdown]
# # Forma habitual de leer y mostrar una imagen (error en colab)

# %%
image = cv2.imread('/content/drive/My drive/Procesamiento PRO/descarga.jfif')
cv2.imshow("Image",image)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-5-74df8337a2bf> in <module>()
#       1 image = cv2.imread('/content/drive/My drive/Procesamiento PRO/descarga.jfif')
# ----> 2 cv2.imshow("Image",image)
#       3 cv2.waitKey(0)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      50   def wrapped(*args, **kwargs):
#      51     if not os.environ.get(env_var, False):
# ---> 52       raise DisabledFunctionError(message, name or func.__name__)
#      53     return func(*args, **kwargs)
#      54
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %%
from google.colab.patches import cv2_imshow
image = cv2.imread('/content/drive/My Drive/Procesamiento PRO/descarga.jfif',cv2.IMREAD_UNCHANGED)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=187x269 at 0x7F33DF703208>

# %% [markdown]
# # como cambiar rutas de folders y archivos opcion uno como
# # cambiar tamaño

# %%
# !pwd
# !ls
#cd ../
# %cd /content/drive/My Drive/Procesamiento PRO/
# !pwd
image = cv2.imread('descarga.jfif',cv2.IMREAD_UNCHANGED)
image = cv2.resize(image,(int(300),int(300)))
cv2_imshow(image)
# Out:
# /content/drive/My Drive/Procesamiento PRO
# descarga.jfif
# /content/drive/My Drive/Procesamiento PRO
# /content/drive/My Drive/Procesamiento PRO
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F33E8828710>

# %% [markdown]
# # SEGUNDA FORMA DE CAMBIAR TAMAÑO

# %%
import os
path='/content/drive/My Drive/Procesamiento PRO/'
os.chdir(path)
# !pwd

from google.colab.patches import cv2_imshow
image = cv2.imread('descarga.jfif',cv2.IMREAD_UNCHANGED)
image = cv2.resize(image,(int(300),int(300)))
cv2_imshow(image)
# Out:
# /content/drive/My Drive/Procesamiento PRO
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FDD7E622A20>

# %% [markdown]
# # crear subfiguras
# (correr codigo anterior
# )

# %%
plt.figure(figsize=(7,7))
plt.imshow(image)
plt.show()
